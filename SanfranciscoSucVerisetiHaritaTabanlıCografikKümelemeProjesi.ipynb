# %% [markdown]
#                              # San Francisco Suc Veriseti Harita Tabanlı Cografik Kümeleme Projesi
#                              (San Francisco Crime Dataset Map-Based Geographic Clustering Project)
#
#
# # San Francisco 1960'larda dünyanın en azılı suçlularından bazılarını barındırmasıyla ünlüydü. Bugün bu projemizde San Francisco Crime Dataset'ini kullanacağız.
#
# # San Francisco was famous for hosting some of the world's most notorious criminals in the 1960s. Today in this project we will be using the San Francisco Crime Dataset.
#
#
# # Veriseti , 2003-2015 yılları arasında San Francisco'da işlenen suçlardan oluşmaktadır. Verisetinde suçlarla ilgili pek çok istatistiksel sütun vardır, ancak kümeleme için yalnızca suç mahalli coğrafi veri sütunlarını (Enlem ve Boylam) kullanacağız.
#
# # The dataset consists of crimes committed in San Francisco between 2003 and 2015. The dataset has many statistical columns related to crimes, but we will only use the crime scene geographic data columns (Latitude and Longitude) for clustering.
#
# # Kümeleme için sadece sayısal verileri kullanmayı amaçladığımız için bu projede sınıflandırma için K-means kümeleme algoritmasını kullanabiliriz.
#
# # Since we aim to use only numerical data for clustering, we can use K-means clustering algorithm for classification in this project.
#
#
#
#
#                                                  # Proje Adımları (Project Steps)
#
#  # 1) Kütüphaneleri içe aktarın, ölçekleyin ve veri setini hazırlayın. (import libraries, scale, and prepare the dataset.)
#
#  # 2) Kaç tane cluster (küme) kullanacağımıza karar vereceğiz. Bunun için de Elbow (dirsek) metodunu kullanacağız. (K değerini bulacağız.)
#        (We will decide how many clusters we will use. For this, we will use the Elbow method. (We will find the K value.))
#  # 3) Modelimizi oluşturup clustering işlemini K-Means Machine Learning algoritması kullanarak yapacağız. (We will create our model and do the clustering process using the K-Means Machine Learning algorithm.)
#
#  # 4) Clustering sonuçlarımızı iyi bilinen harita altlık sistemlerinden biri olan OpenStreetMap cografi Konumlama sistemi üzerinde kullanarak görüntüleyeceğiz.   (We will display our clustering results using the OpenStreetMap geographic positioning system, one of the well-known map base systems.)
#
#  # 5) Son olarak ortaya çıkan cografi haritamızı herhangi bir web sitesinde kolayca kullanılabilmesi için bir html dosyasına aktaracağız. (Finally, we will export our resulting geographic map to an html file so that it can be easily used on any website.)

# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler


df = pd.read_csv("train.csv")
df.head()
# Out:
#                  Dates        Category                      Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y
# 0 -122.425892  37.774599
# 1 -122.425892  37.774599
# 2 -122.424363  37.800414
# 3 -122.426995  37.800873
# ...
